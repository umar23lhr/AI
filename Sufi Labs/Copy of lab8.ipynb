# %%
import numpy as np
import pandas as pd
from sklearn.metrics import precision_score,accuracy_score,recall_score,f1_score,confusion_matrix,ConfusionMatrixDisplay

# %%
X1=np.array([2,4,6,15,30,60,80])
X2=np.array([1,2,7,6,11,14,70])
X3=np.array([3,8,20,4,60,30,13])
Y=np.array([1000,1300,1600,1100,900,3000,2700])

# %%
cor_X1=np.corrcoef(X1,Y)
cor_X2=np.corrcoef(X2,Y)
cor_X3=np.corrcoef(X3,Y)

# %%
mean_x1=np.mean(X1)
mean_x2=np.mean(X2)
mean_x3=np.mean(X3)

meany=np.mean(Y)

# %%
std_X1=np.std(X1)
std_X2=np.std(X2)
std_X3=np.std(X3)
std_Y=np.std(Y)

# %%
SN=(std_X1 - meany)/(std_X1 - std_Y)
print(SN)
# Out:
# 2.1466027370096654

# %%
SN2=(std_X2 - meany)/(std_X2 - std_Y)
print(SN2)
# Out:
# 2.1378043801587783

# %%
SN3=(std_X3 - meany)/(std_X3 - std_Y)
print(SN3)
# Out:
# 2.1321046567882034
