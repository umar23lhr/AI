# %% [markdown]
# # **KNN**

# %%
import numpy as np
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import precision_score,accuracy_score,recall_score,f1_score,confusion_matrix,ConfusionMatrixDisplay

# %%
df=pd.read_csv('/content/data lab5.csv')

# %%
X = df.iloc[:, :3]
Y = df.iloc[:, 3]

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
for k in [2, 4, 6]:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_train, y_train)

    # Predict the target variable
    y_pred = knn.predict(x_test)

    # Calculate evaluation metrics
    accuracy = accuracy_score(y_test, y_pred)

    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    # Generate confusion matrix
    cm = confusion_matrix(y_test, y_pred)
    confusion=confusion_matrix(y_test,pre)
    print(precision)
    print(accuracy)
    print(recall)
    print(F1)
    print(confusion)

import matplotlib.pyplot as plt

confusion_test_plot = ConfusionMatrixDisplay(confusion_matrix=confusion, display_labels=(False, True))
confusion_test_plot.plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-5c3bc31cf69b> in <cell line: 1>()
#       9     accuracy = accuracy_score(y_test, y_pred)
#      10
# ---> 11     recall = recall_score(y_test, y_pred)
#      12     f1 = f1_score(y_test, y_pred)
#      13
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py in recall_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    2096     array([1. , 1. , 0.5])
#    2097     """
# -> 2098     _, r, _, _ = precision_recall_fscore_support(
#    2099         y_true,
#    2100         y_pred,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1571     if beta < 0:
# ...

# %%
pre=model.predict(x_test)
pre
# Out:
# array([1, 3, 1, 2, 2, 3, 3, 3, 2, 2, 2, 2, 1, 1, 1, 2, 3, 1, 3, 1, 1, 2,
#        1, 3, 3, 3, 2, 2, 1, 3, 1, 1, 1, 2, 1, 1, 2, 1, 3, 1, 1, 1, 3, 3,
#        1, 3, 1, 1, 2, 1, 1, 3, 2, 1, 3, 1, 2, 2, 1, 1, 2, 1, 3, 3, 2, 1,
#        2, 2, 1, 2])

# %%
precision=precision_score(y_test,pre)
accuracy=accuracy_score(y_test,pre)
recall=recall_score(y_test,pre)
F1=f1_score(y_test,pre)
confusion=confusion_matrix(y_test,pre)
print(precision)
print(accuracy)
print(recall)
print(F1)
print(confusion)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-27e64ff71e9f> in <cell line: 1>()
# ----> 1 precision=precision_score(y_test,pre)
#       2 accuracy=accuracy_score(y_test,pre)
#       3 recall=recall_score(y_test,pre)
#       4 F1=f1_score(y_test,pre)
#       5 confusion=confusion_matrix(y_test,pre)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py in precision_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1952     array([0.5, 1. , 1. ])
#    1953     """
# -> 1954     p, _, _, _ = precision_recall_fscore_support(
#    1955         y_true,
#    1956         y_pred,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1571     if beta < 0:
# ...

# %%
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt

confusion_test_plot = ConfusionMatrixDisplay(confusion_matrix=confusion, display_labels=(False, True))
confusion_test_plot.plot()
plt.show()
