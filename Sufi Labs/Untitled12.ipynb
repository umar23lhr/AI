# %%
#Import necessary libraries
import numpy as np
import pandas as pd
Import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Linear Regression

#Load the dataset
df = pd.read_csv('/content/Salary_dataset.csv', index_col=8)
#Visualize the scatter plot of Years of Experience vs. Salary plt.scatter(df('Years Experience'], df['Salary'); color="purple') plt.xlabel('YEARS OF EXPERIENCE!) plt.ylabel('SALARY [$]')
Extract features (Years of Experience) and target variable (Salary)
# Out:
#   File "<ipython-input-1-a2ec27628b4f>", line 4
#     Import matplotlib.pyplot as plt
#            ^
# SyntaxError: invalid syntax
