# %%
x=365*24*60*60
y=24*60*60

# %%
print("sec in a year",x)
print("sec in a day",y)
# Out:
# sec in a year 31536000
# sec in a day 86400

# %%
str1="hello"
str2="world"
x=str1+' '+str2
print(x)
# Out:
# hello world

# %%
name=input("Enter your name  ")
age=input("Enter your age   ")
email=input("Enter your student mail ")

print("Students data")
print("Name :",name)
print("Age :",age)
print("Mail :",email)
# Out:
# Enter your name  Sufyan
# Enter your age   23
# Enter your student mail 200509@students.au.edu.pk
# Students data
# Name : Sufyan
# Age : 23
# Mail : 200509@students.au.edu.pk

# %%
name="sufyan mumtaz"
letter=name[0]
print(letter)
print(len(name))
print(name.capitalize())
print(name.upper())
# Out:
# s
# 13
# Sufyan mumtaz
# SUFYAN MUMTAZ

# %%
number=int(input("enter a number "))
if number>=30:
  print("number is correct")
else :
  print("try again")
# Out:
# enter a number 29
# try again

# %%
num=5
print(f"table of {num}")
for i in range (1,11):
  result=num*i
  print(f"5*{i}={result}")
# Out:
# table of 5
# 5*1=5
# 5*2=10
# 5*3=15
# 5*4=20
# 5*5=25
# 5*6=30
# 5*7=35
# 5*8=40
# 5*9=45
# 5*10=50
