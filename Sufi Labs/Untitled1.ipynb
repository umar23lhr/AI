# %%
x=365*24*60*60

# %%
print("Seconds in a year")
# Out:
# Seconds in a year

# %%
x
# Out:
# 31536000

# %%
str1="hello"
str2="world"
x=str1+' '+str2
print(x)
# Out:
# hello world

# %%
name = input("Enter you name")
age = input("Enter your age")
email = input("Enter your email")
print("Student Data")
print("Name :",name)
print("Age :",age)
print("Email :",email)
# Out:
# Enter you nameMoeez Ahmad Qazi
# Enter your age21
# Enter your email200519@students.au.edu.pk
# Student Data
# Name : Moeez Ahmad Qazi
# Age : 21
# Email : 200519@students.au.edu.pk

# %%
name="Moeez Ahmad"
letter=name[0]
print(letter)
print(len(name))
# Out:
# M
# 11

# %%
number=int(input("enter a num"))
if number>=30:
  print("num is correct")
else :
  print("try again")
# Out:
# enter a num35
# num is correct

# %%
num=5
print(f"table of (num)")
for i in range (1,11):
  result=num*i
  print(f"5*{i}={result}")
# Out:
# table of (num)
# 5*1=5
# 5*2=10
# 5*3=15
# 5*4=20
# 5*5=25
# 5*6=30
# 5*7=35
# 5*8=40
# 5*9=45
# 5*10=50
